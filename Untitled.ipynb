# %%
import numpy as np

# %%
import pandas as pd

# %%
from test import *

# %%
from datetime import date

# %%
today = date.today()
year = str(today.year)
month = str(today.month)
day = str(today.day)

# %%
if len(day) == 1:
    day = '0' + day
if len(month) == 1:
    month = '0' + month
iterDate = month + '/' + day + '/' + year
iterDate
# Out:
# '01/07/2022'

# %%
stocks = pd.read_excel('StockScraping.xlsx')

# %%
stocks.head(36)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0          NaN         NaN      STRIKE         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         1.0
# 4          NaN         NaN         NaN         NaN         2.0
# 5          NaN         NaN         NaN         NaN         3.0
# 6          NaN         NaN         NaN         NaN         4.0
# 7          NaN         NaN         NaN         NaN         5.0
# 8          NaN   38.388592         NaN         NaN         6.0
# 9          NaN   22.983708 -104.471399 -287.296348         7.0
# 10         NaN   45.271020  -47.653706         NaN         8.0
# 11         NaN   51.541020  -57.911259  161.065689         9.0
# 12         NaN   45.423763   81.113863   37.232593        10.0
# 13         NaN   32.338824   85.102167   32.338824        11.0
# ...

# %%
#stocks['orig'] = stocks.index

# %%
stocks.head(15)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0          NaN         NaN      STRIKE         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         1.0
# 4          NaN         NaN         NaN         NaN         2.0
# 5          NaN         NaN         NaN         NaN         3.0
# 6          NaN         NaN         NaN         NaN         4.0
# 7          NaN         NaN         NaN         NaN         5.0
# 8          NaN   38.388592         NaN         NaN         6.0
# 9          NaN   22.983708 -104.471399 -287.296348         7.0
# 10         NaN   45.271020  -47.653706         NaN         8.0
# 11         NaN   51.541020  -57.911259  161.065689         9.0
# 12         NaN   45.423763   81.113863   37.232593        10.0
# 13         NaN   32.338824   85.102167   32.338824        11.0
# ...

# %%
tickers = stocks['Unnamed: 6'].dropna().unique()

# %%
tickers
# Out:
# array(['symbol', 'CLR', 'KMI', 'MTDR', 'NOV', 'PTEN', 'RIG', 'RRC', 'SU'],
#       dtype=object)

# %%
tickers = tickers[tickers != 'symbol']

# %%
tickers
# Out:
# array(['CLR', 'KMI', 'MTDR', 'NOV', 'PTEN', 'RIG', 'RRC', 'SU'],
#       dtype=object)

# %%
checkStocks = stocks[stocks['Unnamed: 6'] == 'CLR']

# %%
checkStocks
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 3          NaN         NaN         NaN         NaN         1.0
# 4          NaN         NaN         NaN         NaN         2.0
# 5          NaN         NaN         NaN         NaN         3.0
# 6          NaN         NaN         NaN         NaN         4.0
# 7          NaN         NaN         NaN         NaN         5.0
# 8          NaN   38.388592         NaN         NaN         6.0
# 9          NaN   22.983708 -104.471399 -287.296348         7.0
# 10         NaN   45.271020  -47.653706         NaN         8.0
# 11         NaN   51.541020  -57.911259  161.065689         9.0
# 12         NaN   45.423763   81.113863   37.232593        10.0
# 13         NaN   32.338824   85.102167   32.338824        11.0
# 14         NaN   38.611915  275.799392   68.949848        12.0
# 15         NaN   52.977660  151.364742   49.511831        13.0
# 16         NaN         NaN         NaN         NaN        14.0
# ...

# %%
latestDate = [0, 0, 0]
for idx in checkStocks.index:
    date = str(checkStocks['Unnamed: 15'][idx]).split(' ')
    if date[0] == 'nan':
        continue
    date = date[0].split('-')
    #print(date)
    if int(latestDate[0]) < int(date[0]):
        latestDate = date
        row = int(checkStocks['Unnamed: 4'][idx])
    elif int(latestDate[0]) == int(date[0]):
        if int(latestDate[1]) < int(date[1]):
            latestDate = date
            row = int(checkStocks['Unnamed: 4'][idx])
        elif int(latestDate[1]) == int(date[1]):
            if int(latestDate[2]) < int(date[2]):
                latestDate = date
                row = int(checkStocks['Unnamed: 4'][idx])
print(f'row: {row} date: {latestDate}')
# Out:
# row: 28 date: ['2021', '09', '30']

# %%
pulledData = pd.read_excel('gatheredData.xlsx')

# %%
pulledData
# Out:
#    Unnamed: 0                          stockName mostRecentQuarter  \
# 0           0  Continental Resources, Inc. (CLR)          09/29/21
#
#   profitMargin revenue  revenuePerShare  totalCashPerShare totalDebt  \
# 0       18.31%   4.51B             12.5               1.93     4.76B
#
#    currentRatio  bookValPerShare  operatingCashFlow leveredCashFlow  \
# 0          1.41            19.05         3220000000           1.43B
#
#    sharesOutstanding  currentYearAvgEstimate  nextYearAvgEstimate
# 0          365580000                     4.5                 6.16

# %%
pulledMostRecQ = pulledData['mostRecentQuarter']
p = pulledMostRecQ[0].split('/')

# %%
p
# Out:
# ['09', '29', '21']

# %%
latestDate
latestYear = int(latestDate[0])
latestMonth = int(latestDate[1])
latestYear
# Out:
# 2021

# %%
latestMonth
# Out:
# 9

# %%
pulledMostRecQY = int(p[2]) + 2000
pulledMostRecQY
# Out:
# 2021

# %%
pulledMostRecQM = int(p[0])
pulledMostRecQM
# Out:
# 9

# %%
pulledMostRecQD = int(p[1])
pulledMostRecQD
# Out:
# 29

# %%
if checkMostRecQ(pulled=pulledMostRecQY, curr=latestYear):
    row = int(row) + 1
    stocks.iloc(stocks[stocks['Unnamed: 4'] == row].index)
    pass
else:
    if checkMostRecQ(pulled=pulledMostRecQM, curr=latestMonth):
        row = int(row) + 1
        
        pass
    else:
        pass

# %%
stocks.head(40)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0          NaN         NaN      STRIKE         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         1.0
# 4          NaN         NaN         NaN         NaN         2.0
# 5          NaN         NaN         NaN         NaN         3.0
# 6          NaN         NaN         NaN         NaN         4.0
# 7          NaN         NaN         NaN         NaN         5.0
# 8          NaN   38.388592         NaN         NaN         6.0
# 9          NaN   22.983708 -104.471399 -287.296348         7.0
# 10         NaN   45.271020  -47.653706         NaN         8.0
# 11         NaN   51.541020  -57.911259  161.065689         9.0
# 12         NaN   45.423763   81.113863   37.232593        10.0
# 13         NaN   32.338824   85.102167   32.338824        11.0
# ...

# %%
print(row)
stocks[stocks['Unnamed: 4'] == row].index
# Out:
# 28
# Int64Index([30], dtype='int64')

# %%
stocks
# Out:
#      Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0           NaN         NaN     STRIKE         NaN         NaN
# 1           NaN         NaN        NaN         NaN         NaN
# 2           NaN         NaN        NaN         NaN         NaN
# 3           NaN         NaN        NaN         NaN         1.0
# 4           NaN         NaN        NaN         NaN         2.0
# ..          ...         ...        ...         ...         ...
# 262         NaN         NaN        NaN         NaN       326.0
# 263         NaN         NaN        NaN         NaN       327.0
# 264         NaN         NaN        NaN         NaN       328.0
# 265         NaN         NaN        NaN         NaN       329.0
# 266         NaN         NaN        NaN         NaN       330.0
#
#                 Unnamed: 5 Unnamed: 6 Unnamed: 7   Unnamed: 8   Unnamed: 9  \
# 0                  Company     symbol        NaT  share price  One Yr. Pot
# ...

# %%
stocks['Unnamed: 2'][3] = 'bye'
# Out:
# /var/folders/xt/5b4knh4j39l3kh5j0d6jhmdc0000gn/T/ipykernel_82624/2851361984.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stocks['Unnamed: 2'][3] = 'bye'

# %%
stocks.head
# Out:
# <bound method NDFrame.head of     Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0          NaN         NaN     STRIKE         NaN         NaN
# 1          NaN         NaN        NaN         NaN         NaN
# 2          NaN         NaN        NaN         NaN         NaN
# 3          bye         NaN        NaN         NaN         1.0
# 4          NaN         NaN        NaN         NaN         2.0
# ..         ...         ...        ...         ...         ...
# 262        NaN         NaN        NaN         NaN       326.0
# 263        NaN         NaN        NaN         NaN       327.0
# 264        NaN         NaN        NaN         NaN       328.0
# 265        NaN         NaN        NaN         NaN       329.0
# 266        NaN         NaN        NaN         NaN       330.0
#
#                 Unnamed: 5 Unnamed: 6 Unnamed: 7   Unnamed: 8   Unnamed: 9  \
# 0                  Company     symbol        NaT  share price  One Yr. Pot
# ...

# %%
stocks.iloc[0]
# Out:
# Unnamed: 0                                                               NaN
# Unnamed: 1                                                               NaN
# Unnamed: 2                                                            STRIKE
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
# Unnamed: 5                                                           Company
# Unnamed: 6                                                            symbol
# Unnamed: 7                                                               NaT
# Unnamed: 8                                                       share price
# Unnamed: 9                                                       One Yr. Pot
# Unnamed: 10                                                              NaN
# Earnings -----------------------------------------             Earnings - PY
# ...

# %%
{'stockName': [stockName],
 'mostRecentQuarter': [mostRecentQuarter],
 'profitMargin': [profitMargin], 
 'revenue': [revenue], 
 'revenuePerShare': [revenuePerShare], 
 'totalCashPerShare': [totalCashPerShare], 
 'totalDebt': [totalDebt], 
 'currentRatio': [currentRatio], 
 'bookValPerShare': [bookValPerShare], 
 'operatingCashFlow': [operatingCashFlow], 
 'leveredCashFlow': [leveredCashFlow], 
 'sharesOutstanding': [sharesOutstanding], 
 'currentYearAvgEstimate': [currentYearAvgEstimate], 
 'nextYearAvgEstimate': [nextYearAvgEstimate]}
